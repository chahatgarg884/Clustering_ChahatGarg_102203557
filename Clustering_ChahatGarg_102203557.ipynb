# %% [markdown]
# <a href="https://colab.research.google.com/github/chahatgarg884/Clustering_ChahatGarg_102203557/blob/main/Clustering_ChahatGarg_102203557.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_iris
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans, AgglomerativeClustering, MeanShift
from sklearn.metrics import silhouette_score, calinski_harabasz_score, davies_bouldin_score
import pandas as pd
import numpy as np
from warnings import filterwarnings
filterwarnings("ignore")

# Load dataset
iris = load_iris()
X_original = pd.DataFrame(iris.data, columns=iris.feature_names)

# Preprocessing functions
def no_processing(X): return X.copy()
def normalize(X): return MinMaxScaler().fit_transform(X)
def transform(X): return np.sqrt(np.abs(X))
def apply_pca(X): return PCA(n_components=2).fit_transform(X)
def transform_then_normalize(X): return normalize(transform(X))
def t_n_pca(X): return apply_pca(transform_then_normalize(X))

preprocessing_methods = {
    "No Processing": no_processing,
    "Normalization": normalize,
    "Transform": transform,
    "PCA": lambda X: apply_pca(X),
    "T+N": transform_then_normalize,
    "T+N+PCA": t_n_pca,
}

cluster_range = [3, 4, 5]
results = []

# ================================
# Evaluate each algorithm
# ================================
for method_name, preprocess in preprocessing_methods.items():
    try:
        X_proc = preprocess(X_original)
    except Exception as e:
        print(f"[ERROR] Preprocessing failed for {method_name}: {e}")
        continue

    # --- KMeans ---
    for k in cluster_range:
        try:
            model = KMeans(n_clusters=k, random_state=42, n_init='auto').fit(X_proc)
            labels = model.labels_
            sil = silhouette_score(X_proc, labels)
            cal = calinski_harabasz_score(X_proc, labels)
            db = davies_bouldin_score(X_proc, labels)
            results.append({
                "Algorithm": "KMeans",
                "Method": method_name,
                "Clusters": k,
                "Silhouette": round(sil, 2),
                "Calinski-Harabasz": round(cal),
                "Davies-Bouldin": round(db, 2)
            })
        except Exception as e:
            print(f"KMeans failed for {method_name} with k={k}: {e}")

    # --- Hierarchical (Agglomerative) ---
    for k in cluster_range:
        try:
            model = AgglomerativeClustering(n_clusters=k).fit(X_proc)
            labels = model.labels_
            sil = silhouette_score(X_proc, labels)
            cal = calinski_harabasz_score(X_proc, labels)
            db = davies_bouldin_score(X_proc, labels)
            results.append({
                "Algorithm": "Hierarchical",
                "Method": method_name,
                "Clusters": k,
                "Silhouette": round(sil, 2),
                "Calinski-Harabasz": round(cal),
                "Davies-Bouldin": round(db, 2)
            })
        except Exception as e:
            print(f"Hierarchical failed for {method_name} with k={k}: {e}")

    # --- Mean Shift (no need to specify k) ---
    try:
        model = MeanShift().fit(X_proc)
        labels = model.labels_
        sil = silhouette_score(X_proc, labels)
        cal = calinski_harabasz_score(X_proc, labels)
        db = davies_bouldin_score(X_proc, labels)
        results.append({
            "Algorithm": "MeanShift",
            "Method": method_name,
            "Clusters": len(np.unique(labels)),
            "Silhouette": round(sil, 2),
            "Calinski-Harabasz": round(cal),
            "Davies-Bouldin": round(db, 2)
        })
    except Exception as e:
        print(f"MeanShift failed for {method_name}: {e}")

# Final DataFrame
results_df = pd.DataFrame(results)
results_df
# Out:
#        Algorithm         Method  Clusters  Silhouette  Calinski-Harabasz  \
# 0         KMeans  No Processing         3        0.55                562
# 1         KMeans  No Processing         4        0.50                530
# 2         KMeans  No Processing         5        0.49                495
# 3   Hierarchical  No Processing         3        0.55                558
# 4   Hierarchical  No Processing         4        0.49                515
# 5   Hierarchical  No Processing         5        0.48                488
# 6      MeanShift  No Processing         2        0.69                510
# 7         KMeans  Normalization         3        0.48                351
# 8         KMeans  Normalization         4        0.44                314
# 9         KMeans  Normalization         5        0.42                263
# 10  Hierarchical  Normalization         3        0.50                349
# 11  Hierarchical  Normalization         4        0.43                301
# 12  Hierarchical  Normalization         5        0.35                272
# 13     MeanShift  Normalization         2        0.63                354
# 14        KMeans      Transform         3        0.56                434
# 15        KMeans      Transform         4        0.39                604
# 16        KMeans      Transform         5        0.33                614
# 17  Hierarchical      Transform         3        0.55                789
# 18  Hierarchical      Transform         4        0.49                700
# 19  Hierarchical      Transform         5        0.34                592
# 20     MeanShift      Transform         2        0.75                821
# 21        KMeans            PCA         3        0.60                694
# 22        KMeans            PCA         4        0.56                719
# 23        KMeans            PCA         5        0.51                642
# 24  Hierarchical            PCA         3        0.60                689
# 25  Hierarchical            PCA         4        0.54                674
# 26  Hierarchical            PCA         5        0.55                666
# 27     MeanShift            PCA         2        0.71                566
# 28        KMeans            T+N         3        0.54                258
# 29        KMeans            T+N         4        0.37                332
# 30        KMeans            T+N         5        0.33                323
# 31  Hierarchical            T+N         3        0.48                393
# 32  Hierarchical            T+N         4        0.43                335
# 33  Hierarchical            T+N         5        0.32                311
# 34     MeanShift            T+N         2        0.67                458
# 35        KMeans        T+N+PCA         3        0.55                540
# 36        KMeans        T+N+PCA         4        0.45                456
# 37        KMeans        T+N+PCA         5        0.42                490
# 38  Hierarchical        T+N+PCA         3        0.54                498
# 39  Hierarchical        T+N+PCA         4        0.50                466
# 40  Hierarchical        T+N+PCA         5        0.41                463
# 41     MeanShift        T+N+PCA         2        0.70                535
#
#     Davies-Bouldin
# 0             0.67
# 1             0.75
# 2             0.82
# 3             0.66
# 4             0.80
# 5             0.82
# 6             0.39
# 7             0.79
# 8             0.91
# 9             0.99
# 10            0.75
# 11            0.85
# 12            0.91
# 13            0.49
# 14            0.92
# 15            1.03
# 16            1.07
# 17            0.65
# 18            0.74
# 19            0.96
# 20            0.32
# 21            0.56
# 22            0.62
# 23            0.75
# 24            0.56
# 25            0.65
# 26            0.65
# 27            0.36
# 28            0.77
# 29            0.95
# 30            1.02
# 31            0.77
# 32            0.89
# 33            1.01
# 34            0.45
# 35            0.65
# 36            0.77
# 37            0.79
# 38            0.61
# 39            0.75
# 40            0.82
# 41            0.40
